# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorEBR/Algoritmo-2/blob/main/Primeira_Aula_Algoritimo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#numpy  biblioteca para manipulação matemática
import numpy as np
#pandas lib para manipulação de dados
import pandas as pd

# %%
lista = [7,9,13,2,8]

# %%
print(lista)
# Out:
# [7, 9, 13, 2, 8]

# %%
lista2 = np.array(lista) * 2

# %%
print(lista2)
# Out:
# [14 18 26  4 16]

# %%
def soma(a, b):
  return a + b

# %%
w = soma(lista2,lista)

# %%
print(w)
# Out:
# [21 27 39  6 24]
