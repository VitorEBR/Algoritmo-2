# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorEBR/Algoritmo-2/blob/main/Quarta_Aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista = [50,1,0,60,13,24,99,102,64,78,95,10000,85274,46519465498,488494794651465,44644,31122,55733,555476993663,1444987,112204,333,412]

# %%
def quicksort(lista):
  if len(lista)<=1:
    return lista
  pivo=lista[0]
  menores=[x for x in lista[1:] if x <pivo]
  maiores=[x for x in lista[1:]if x >=pivo]
  return quicksort(menores)+[pivo]+quicksort(maiores)

# %%
quicksort(lista)
# Out:
# [0,
#  1,
#  13,
#  24,
#  50,
#  60,
#  64,
#  78,
#  95,
#  99,
#  102,
#  333,
#  412,
#  10000,
#  31122,
#  44644,
#  55733,
#  85274,
#  112204,
#  1444987,
#  46519465498,
#  555476993663,
#  488494794651465]

# %%
from types import MemberDescriptorType
def quicksort(lista):
  if len(lista)<=1:
    return lista
  pivo=lista[len(lista)//2]
  menores = [x for x in lista if x<pivo]
  meio = [x for x in lista if x==pivo]
  maiores=[x for x in lista if x>pivo]
  return quicksort(menores)+meio+quicksort(maiores)

# %%
quicksort (lista)
# Out:
# [0,
#  1,
#  13,
#  24,
#  50,
#  60,
#  64,
#  78,
#  95,
#  99,
#  102,
#  333,
#  412,
#  10000,
#  31122,
#  44644,
#  55733,
#  85274,
#  112204,
#  1444987,
#  46519465498,
#  555476993663,
#  488494794651465]

# %%
def bubblesort(lista):
  n=len(lista)
  for i in range(n):
    for j in range(n-i-1):
      if lista[j]>lista[j+1]:
        lista[j],lista[j+1]=lista[j+1],lista[j]
  return lista

# %%
bubblesort(lista)
# Out:
# [0,
#  1,
#  13,
#  24,
#  50,
#  60,
#  64,
#  78,
#  95,
#  99,
#  102,
#  333,
#  412,
#  10000,
#  31122,
#  44644,
#  55733,
#  85274,
#  112204,
#  1444987,
#  46519465498,
#  555476993663,
#  488494794651465]

# %%
def MergeSort (lista):
  if len(lista)<=1:
    return lista
  meio= len(lista)//2
  esq= MergeSort(lista[:meio])
  dir= MergeSort(lista[meio:])
  return Merge(esq,dir)
def Merge(esq,dir):
  resultado=[]
  i=j=0
  while (i<len(esq) and j<len(dir)):
    if esq[i]<dir[j]:
      resultado.append(esq[i])
      i+=1
    else:
      resultado.append(dir[j])
      j+=1
    resultado.extend(esq[i:])
    resultado.extend(dir[j:])
    return resultado

# %%
MergeSort(lista)
# Out:
# [0,
#  1,
#  13,
#  24,
#  50,
#  60,
#  64,
#  78,
#  95,
#  99,
#  102,
#  333,
#  412,
#  10000,
#  31122,
#  44644,
#  55733,
#  85274,
#  112204,
#  1444987,
#  46519465498,
#  555476993663,
#  488494794651465]
